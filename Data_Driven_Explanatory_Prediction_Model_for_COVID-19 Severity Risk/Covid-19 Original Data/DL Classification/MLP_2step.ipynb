# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

# Load the dataset
file_path = '/Final_dataset_Classific.xlsx'
dataset = pd.read_excel(file_path)
cols_to_drop = dataset.filter(like='Medication_').columns
dataset = dataset.drop(columns=cols_to_drop)

# Split the dataset into training and test sets
train_data, test_data = train_test_split(dataset, test_size=0.45, random_state=42)

# Prepare data for the classification task
train_data['Outcome_numerical_step1'] = train_data['Outcome_numerical'].replace(2, 0)
X_train = train_data.drop(columns=['Outcome_numerical', 'Outcome_numerical_step1'])
y_train = train_data['Outcome_numerical_step1']

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Function to build the model
def build_model(input_dim, dropout_rate=0.25):
    model = Sequential([
        Dense(128, activation='relu', input_dim=input_dim),
        Dropout(dropout_rate),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Train the model with 10-fold cross-validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
fold_no = 1
losses = []
accuracies = []

for train, test in kfold.split(X_train_scaled, y_train):
    model = build_model(X_train_scaled.shape[1])
    print(f'Training for fold {fold_no}...')

    # Fit data to model
    history = model.fit(X_train_scaled[train], y_train.iloc[train],
                        batch_size=32,
                        epochs=25,
                        verbose=1,
                        validation_data=(X_train_scaled[test], y_train.iloc[test]))

    # Generate generalization metrics
    scores = model.evaluate(X_train_scaled[test], y_train.iloc[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    accuracies.append(scores[1] * 100)
    losses.append(scores[0])
    fold_no += 1

print(f'Average Accuracy: {np.mean(accuracies)}%')
print(f'Average Loss: {np.mean(losses)}')

# Prepare the test set
X_test = test_data.drop(columns=['Outcome_numerical'])
X_test_scaled = scaler.transform(X_test)

# Make predictions on the test set
test_data['Predicted_step1'] = (model.predict(X_test_scaled) > 0.5).astype(int)

# Define y_test for evaluating the performance of predictions
y_test = test_data['Outcome_numerical'].replace(2, 0)
y_pred_step1 = test_data['Predicted_step1']

# Calculate and display the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_step1)

# Visualize the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
disp.plot(cmap=plt.cm.Blues, ax=ax)
ax.set_title('Confusion Matrix for MLP Classifier')
plt.show()
# Out:
# Training for fold 1...
# Epoch 1/25
# 8/8 [==============================] - 3s 47ms/step - loss: 0.7072 - accuracy: 0.5647 - val_loss: 0.6020 - val_accuracy: 0.6923
# Epoch 2/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5298 - accuracy: 0.7586 - val_loss: 0.5167 - val_accuracy: 0.7692
# Epoch 3/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4342 - accuracy: 0.8276 - val_loss: 0.4641 - val_accuracy: 0.8846
# Epoch 4/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3687 - accuracy: 0.8793 - val_loss: 0.4160 - val_accuracy: 0.8462
# Epoch 5/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3263 - accuracy: 0.8836 - val_loss: 0.3935 - val_accuracy: 0.8462
# Epoch 6/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.2657 - accuracy: 0.9052 - val_loss: 0.3709 - val_accuracy: 0.8846
# Epoch 7/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2506 - accuracy: 0.9181 - val_loss: 0.3634 - val_accuracy: 0.8462
# Epoch 8/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.2104 - accuracy: 0.9353 - val_loss: 0.3559 - val_accuracy: 0.8077
# Epoch 9/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1832 - accuracy: 0.9569 - val_loss: 0.3409 - val_accuracy: 0.8077
# Epoch 10/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1828 - accuracy: 0.9267 - val_loss: 0.3388 - val_accuracy: 0.8077
# Epoch 11/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1479 - accuracy: 0.9483 - val_loss: 0.3595 - val_accuracy: 0.8077
# Epoch 12/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1464 - accuracy: 0.9483 - val_loss: 0.3768 - val_accuracy: 0.8077
# Epoch 13/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1236 - accuracy: 0.9698 - val_loss: 0.3657 - val_accuracy: 0.8077
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1126 - accuracy: 0.9655 - val_loss: 0.3644 - val_accuracy: 0.8077
# Epoch 15/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0927 - accuracy: 0.9784 - val_loss: 0.3659 - val_accuracy: 0.8077
# Epoch 16/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0854 - accuracy: 0.9828 - val_loss: 0.3681 - val_accuracy: 0.8077
# Epoch 17/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0854 - accuracy: 0.9784 - val_loss: 0.3752 - val_accuracy: 0.8077
# Epoch 18/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0747 - accuracy: 0.9828 - val_loss: 0.3828 - val_accuracy: 0.8077
# Epoch 19/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0614 - accuracy: 0.9914 - val_loss: 0.3953 - val_accuracy: 0.8462
# Epoch 20/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0630 - accuracy: 0.9914 - val_loss: 0.3739 - val_accuracy: 0.8462
# Epoch 21/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0480 - accuracy: 1.0000 - val_loss: 0.3578 - val_accuracy: 0.8077
# Epoch 22/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0428 - accuracy: 1.0000 - val_loss: 0.3593 - val_accuracy: 0.8462
# Epoch 23/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0412 - accuracy: 0.9871 - val_loss: 0.3704 - val_accuracy: 0.8462
# Epoch 24/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0376 - accuracy: 0.9957 - val_loss: 0.3723 - val_accuracy: 0.8462
# Epoch 25/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.3749 - val_accuracy: 0.8462
# Score for fold 1: loss of 0.3749188780784607; accuracy of 84.61538553237915%
# Training for fold 2...
# Epoch 1/25
# 8/8 [==============================] - 1s 30ms/step - loss: 0.6989 - accuracy: 0.5000 - val_loss: 0.6380 - val_accuracy: 0.6923
# Epoch 2/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5627 - accuracy: 0.7500 - val_loss: 0.5597 - val_accuracy: 0.7692
# Epoch 3/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4748 - accuracy: 0.8147 - val_loss: 0.4778 - val_accuracy: 0.7692
# Epoch 4/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3850 - accuracy: 0.9052 - val_loss: 0.4167 - val_accuracy: 0.8462
# Epoch 5/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3555 - accuracy: 0.8922 - val_loss: 0.3826 - val_accuracy: 0.8462
# Epoch 6/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.2979 - accuracy: 0.9138 - val_loss: 0.3619 - val_accuracy: 0.8462
# Epoch 7/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2526 - accuracy: 0.9138 - val_loss: 0.3512 - val_accuracy: 0.8462
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2332 - accuracy: 0.9224 - val_loss: 0.3307 - val_accuracy: 0.8462
# Epoch 9/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.2055 - accuracy: 0.9267 - val_loss: 0.3167 - val_accuracy: 0.8846
# Epoch 10/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2015 - accuracy: 0.9267 - val_loss: 0.3092 - val_accuracy: 0.8846
# Epoch 11/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1715 - accuracy: 0.9440 - val_loss: 0.3015 - val_accuracy: 0.8846
# Epoch 12/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1507 - accuracy: 0.9440 - val_loss: 0.3014 - val_accuracy: 0.8846
# Epoch 13/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1433 - accuracy: 0.9526 - val_loss: 0.3180 - val_accuracy: 0.8846
# Epoch 14/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1410 - accuracy: 0.9483 - val_loss: 0.3073 - val_accuracy: 0.8846
# Epoch 15/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1242 - accuracy: 0.9526 - val_loss: 0.3036 - val_accuracy: 0.8846
# Epoch 16/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1097 - accuracy: 0.9784 - val_loss: 0.3034 - val_accuracy: 0.8846
# Epoch 17/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0904 - accuracy: 0.9698 - val_loss: 0.3219 - val_accuracy: 0.8846
# Epoch 18/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0764 - accuracy: 0.9741 - val_loss: 0.3345 - val_accuracy: 0.8846
# Epoch 19/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0918 - accuracy: 0.9698 - val_loss: 0.3283 - val_accuracy: 0.8846
# Epoch 20/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0647 - accuracy: 0.9914 - val_loss: 0.3206 - val_accuracy: 0.8846
# Epoch 21/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0595 - accuracy: 0.9957 - val_loss: 0.3166 - val_accuracy: 0.8846
# Epoch 22/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0599 - accuracy: 0.9914 - val_loss: 0.3176 - val_accuracy: 0.8846
# Epoch 23/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0552 - accuracy: 0.9957 - val_loss: 0.3406 - val_accuracy: 0.8846
# Epoch 24/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0448 - accuracy: 0.9914 - val_loss: 0.3387 - val_accuracy: 0.8846
# Epoch 25/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0531 - accuracy: 0.9871 - val_loss: 0.3469 - val_accuracy: 0.8846
# Score for fold 2: loss of 0.346938818693161; accuracy of 88.46153616905212%
# Training for fold 3...
# Epoch 1/25
# 8/8 [==============================] - 1s 31ms/step - loss: 0.6605 - accuracy: 0.6078 - val_loss: 0.6242 - val_accuracy: 0.6154
# Epoch 2/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5463 - accuracy: 0.7543 - val_loss: 0.5814 - val_accuracy: 0.8462
# Epoch 3/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4430 - accuracy: 0.8190 - val_loss: 0.5412 - val_accuracy: 0.6923
# Epoch 4/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3815 - accuracy: 0.8750 - val_loss: 0.5258 - val_accuracy: 0.6538
# Epoch 5/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3355 - accuracy: 0.8836 - val_loss: 0.5238 - val_accuracy: 0.7308
# Epoch 6/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2883 - accuracy: 0.9009 - val_loss: 0.5241 - val_accuracy: 0.7692
# Epoch 7/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2460 - accuracy: 0.9310 - val_loss: 0.5284 - val_accuracy: 0.7692
# Epoch 8/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2199 - accuracy: 0.9009 - val_loss: 0.5290 - val_accuracy: 0.7692
# Epoch 9/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1750 - accuracy: 0.9397 - val_loss: 0.5371 - val_accuracy: 0.7308
# Epoch 10/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1667 - accuracy: 0.9526 - val_loss: 0.5495 - val_accuracy: 0.7692
# Epoch 11/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1563 - accuracy: 0.9440 - val_loss: 0.5597 - val_accuracy: 0.6923
# Epoch 12/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1452 - accuracy: 0.9569 - val_loss: 0.5687 - val_accuracy: 0.6923
# Epoch 13/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1190 - accuracy: 0.9612 - val_loss: 0.5767 - val_accuracy: 0.7692
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1109 - accuracy: 0.9655 - val_loss: 0.5930 - val_accuracy: 0.7692
# Epoch 15/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0973 - accuracy: 0.9655 - val_loss: 0.6049 - val_accuracy: 0.7308
# Epoch 16/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1017 - accuracy: 0.9655 - val_loss: 0.6134 - val_accuracy: 0.6923
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0936 - accuracy: 0.9655 - val_loss: 0.6305 - val_accuracy: 0.6923
# Epoch 18/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0813 - accuracy: 0.9655 - val_loss: 0.6329 - val_accuracy: 0.7692
# Epoch 19/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0646 - accuracy: 0.9871 - val_loss: 0.6473 - val_accuracy: 0.7692
# Epoch 20/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0587 - accuracy: 0.9871 - val_loss: 0.6455 - val_accuracy: 0.7308
# Epoch 21/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0677 - accuracy: 0.9871 - val_loss: 0.6551 - val_accuracy: 0.7308
# Epoch 22/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0633 - accuracy: 1.0000 - val_loss: 0.6767 - val_accuracy: 0.7692
# Epoch 23/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0491 - accuracy: 0.9957 - val_loss: 0.7012 - val_accuracy: 0.8077
# Epoch 24/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0464 - accuracy: 0.9957 - val_loss: 0.7049 - val_accuracy: 0.7692
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0413 - accuracy: 0.9957 - val_loss: 0.7131 - val_accuracy: 0.7692
# Score for fold 3: loss of 0.7130715847015381; accuracy of 76.92307829856873%
# Training for fold 4...
# Epoch 1/25
# 8/8 [==============================] - 1s 30ms/step - loss: 0.7362 - accuracy: 0.5172 - val_loss: 0.5483 - val_accuracy: 0.7692
# Epoch 2/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5132 - accuracy: 0.7586 - val_loss: 0.4688 - val_accuracy: 0.8462
# Epoch 3/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4376 - accuracy: 0.8405 - val_loss: 0.4101 - val_accuracy: 0.8462
# Epoch 4/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3734 - accuracy: 0.8707 - val_loss: 0.3826 - val_accuracy: 0.8462
# Epoch 5/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2919 - accuracy: 0.9052 - val_loss: 0.3701 - val_accuracy: 0.8077
# Epoch 6/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2879 - accuracy: 0.9052 - val_loss: 0.3732 - val_accuracy: 0.8077
# Epoch 7/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2403 - accuracy: 0.9224 - val_loss: 0.3744 - val_accuracy: 0.8077
# Epoch 8/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2076 - accuracy: 0.9310 - val_loss: 0.3836 - val_accuracy: 0.8077
# Epoch 9/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1910 - accuracy: 0.9310 - val_loss: 0.3959 - val_accuracy: 0.8077
# Epoch 10/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1633 - accuracy: 0.9526 - val_loss: 0.4154 - val_accuracy: 0.8077
# Epoch 11/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1609 - accuracy: 0.9569 - val_loss: 0.4311 - val_accuracy: 0.8077
# Epoch 12/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1404 - accuracy: 0.9569 - val_loss: 0.4344 - val_accuracy: 0.8077
# Epoch 13/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1298 - accuracy: 0.9612 - val_loss: 0.4372 - val_accuracy: 0.8077
# Epoch 14/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1263 - accuracy: 0.9569 - val_loss: 0.4426 - val_accuracy: 0.8077
# Epoch 15/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0989 - accuracy: 0.9698 - val_loss: 0.4563 - val_accuracy: 0.8077
# Epoch 16/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0950 - accuracy: 0.9828 - val_loss: 0.4599 - val_accuracy: 0.8077
# Epoch 17/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0949 - accuracy: 0.9698 - val_loss: 0.4741 - val_accuracy: 0.8077
# Epoch 18/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0758 - accuracy: 0.9828 - val_loss: 0.4917 - val_accuracy: 0.8077
# Epoch 19/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0696 - accuracy: 0.9871 - val_loss: 0.5154 - val_accuracy: 0.8077
# Epoch 20/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0637 - accuracy: 0.9914 - val_loss: 0.5352 - val_accuracy: 0.8077
# Epoch 21/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0597 - accuracy: 0.9871 - val_loss: 0.5546 - val_accuracy: 0.8077
# Epoch 22/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0499 - accuracy: 0.9914 - val_loss: 0.5893 - val_accuracy: 0.8077
# Epoch 23/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0463 - accuracy: 0.9914 - val_loss: 0.6204 - val_accuracy: 0.8077
# Epoch 24/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0445 - accuracy: 0.9957 - val_loss: 0.6366 - val_accuracy: 0.8077
# Epoch 25/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0398 - accuracy: 0.9914 - val_loss: 0.6509 - val_accuracy: 0.8077
# Score for fold 4: loss of 0.6509296894073486; accuracy of 80.7692289352417%
# Training for fold 5...
# Epoch 1/25
# 8/8 [==============================] - 1s 31ms/step - loss: 0.7440 - accuracy: 0.5216 - val_loss: 0.6788 - val_accuracy: 0.6923
# Epoch 2/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5773 - accuracy: 0.7284 - val_loss: 0.6062 - val_accuracy: 0.7308
# Epoch 3/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4905 - accuracy: 0.8017 - val_loss: 0.5427 - val_accuracy: 0.8077
# Epoch 4/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4202 - accuracy: 0.8621 - val_loss: 0.4907 - val_accuracy: 0.8846
# Epoch 5/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3636 - accuracy: 0.8750 - val_loss: 0.4615 - val_accuracy: 0.8846
# Epoch 6/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3144 - accuracy: 0.8966 - val_loss: 0.4402 - val_accuracy: 0.8846
# Epoch 7/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2864 - accuracy: 0.8966 - val_loss: 0.4290 - val_accuracy: 0.8846
# Epoch 8/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2465 - accuracy: 0.9138 - val_loss: 0.4234 - val_accuracy: 0.8846
# Epoch 9/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2323 - accuracy: 0.9181 - val_loss: 0.4226 - val_accuracy: 0.8846
# Epoch 10/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2079 - accuracy: 0.9224 - val_loss: 0.4228 - val_accuracy: 0.8846
# Epoch 11/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1837 - accuracy: 0.9353 - val_loss: 0.4252 - val_accuracy: 0.8846
# Epoch 12/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1716 - accuracy: 0.9526 - val_loss: 0.4262 - val_accuracy: 0.8846
# Epoch 13/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1555 - accuracy: 0.9440 - val_loss: 0.4233 - val_accuracy: 0.8846
# Epoch 14/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1335 - accuracy: 0.9483 - val_loss: 0.4286 - val_accuracy: 0.8846
# Epoch 15/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1248 - accuracy: 0.9569 - val_loss: 0.4399 - val_accuracy: 0.8846
# Epoch 16/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1009 - accuracy: 0.9871 - val_loss: 0.4440 - val_accuracy: 0.8846
# Epoch 17/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0913 - accuracy: 0.9871 - val_loss: 0.4578 - val_accuracy: 0.8846
# Epoch 18/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1016 - accuracy: 0.9698 - val_loss: 0.4728 - val_accuracy: 0.8846
# Epoch 19/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0767 - accuracy: 0.9914 - val_loss: 0.4811 - val_accuracy: 0.8846
# Epoch 20/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0723 - accuracy: 0.9741 - val_loss: 0.4910 - val_accuracy: 0.8846
# Epoch 21/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0547 - accuracy: 0.9914 - val_loss: 0.4997 - val_accuracy: 0.8846
# Epoch 22/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0672 - accuracy: 0.9828 - val_loss: 0.5071 - val_accuracy: 0.8846
# Epoch 23/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0495 - accuracy: 0.9914 - val_loss: 0.5205 - val_accuracy: 0.8846
# Epoch 24/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0477 - accuracy: 0.9914 - val_loss: 0.5342 - val_accuracy: 0.8846
# Epoch 25/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0424 - accuracy: 0.9914 - val_loss: 0.5394 - val_accuracy: 0.8846
# Score for fold 5: loss of 0.5393661856651306; accuracy of 88.46153616905212%
# Training for fold 6...
# Epoch 1/25
# 8/8 [==============================] - 1s 29ms/step - loss: 0.6019 - accuracy: 0.7026 - val_loss: 0.5125 - val_accuracy: 0.7308
# Epoch 2/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4607 - accuracy: 0.8362 - val_loss: 0.4734 - val_accuracy: 0.7308
# Epoch 3/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3799 - accuracy: 0.8664 - val_loss: 0.4528 - val_accuracy: 0.7308
# Epoch 4/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3259 - accuracy: 0.8879 - val_loss: 0.4574 - val_accuracy: 0.7308
# Epoch 5/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2929 - accuracy: 0.8879 - val_loss: 0.4650 - val_accuracy: 0.7308
# Epoch 6/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2315 - accuracy: 0.9397 - val_loss: 0.4853 - val_accuracy: 0.7308
# Epoch 7/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1937 - accuracy: 0.9310 - val_loss: 0.5034 - val_accuracy: 0.7308
# Epoch 8/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1867 - accuracy: 0.9310 - val_loss: 0.5301 - val_accuracy: 0.7308
# Epoch 9/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1703 - accuracy: 0.9483 - val_loss: 0.5654 - val_accuracy: 0.7308
# Epoch 10/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1349 - accuracy: 0.9569 - val_loss: 0.5698 - val_accuracy: 0.7308
# Epoch 11/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1386 - accuracy: 0.9655 - val_loss: 0.5847 - val_accuracy: 0.7308
# Epoch 12/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1186 - accuracy: 0.9526 - val_loss: 0.6187 - val_accuracy: 0.7308
# Epoch 13/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1134 - accuracy: 0.9569 - val_loss: 0.6549 - val_accuracy: 0.7308
# Epoch 14/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0918 - accuracy: 0.9784 - val_loss: 0.6814 - val_accuracy: 0.7308
# Epoch 15/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0806 - accuracy: 0.9828 - val_loss: 0.7132 - val_accuracy: 0.7308
# Epoch 16/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0780 - accuracy: 0.9784 - val_loss: 0.7633 - val_accuracy: 0.7308
# Epoch 17/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0644 - accuracy: 0.9828 - val_loss: 0.8005 - val_accuracy: 0.7308
# Epoch 18/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0618 - accuracy: 0.9871 - val_loss: 0.8273 - val_accuracy: 0.7308
# Epoch 19/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0545 - accuracy: 0.9914 - val_loss: 0.8614 - val_accuracy: 0.7308
# Epoch 20/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0550 - accuracy: 0.9828 - val_loss: 0.8831 - val_accuracy: 0.7308
# Epoch 21/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0506 - accuracy: 0.9914 - val_loss: 0.9337 - val_accuracy: 0.7308
# Epoch 22/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0356 - accuracy: 1.0000 - val_loss: 0.9742 - val_accuracy: 0.7308
# Epoch 23/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.9946 - val_accuracy: 0.7308
# Epoch 24/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 1.0042 - val_accuracy: 0.7308
# Epoch 25/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0335 - accuracy: 0.9957 - val_loss: 1.0224 - val_accuracy: 0.7308
# Score for fold 6: loss of 1.0224305391311646; accuracy of 73.07692170143127%
# Training for fold 7...
# Epoch 1/25
# 8/8 [==============================] - 1s 49ms/step - loss: 0.6609 - accuracy: 0.6164 - val_loss: 0.6378 - val_accuracy: 0.6923
# Epoch 2/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5278 - accuracy: 0.7543 - val_loss: 0.5858 - val_accuracy: 0.7692
# Epoch 3/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4390 - accuracy: 0.8448 - val_loss: 0.5476 - val_accuracy: 0.7692
# Epoch 4/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3733 - accuracy: 0.8621 - val_loss: 0.5257 - val_accuracy: 0.7692
# Epoch 5/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3166 - accuracy: 0.8664 - val_loss: 0.5134 - val_accuracy: 0.7692
# Epoch 6/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2614 - accuracy: 0.9138 - val_loss: 0.4998 - val_accuracy: 0.7692
# Epoch 7/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2423 - accuracy: 0.9310 - val_loss: 0.4917 - val_accuracy: 0.7692
# Epoch 8/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2059 - accuracy: 0.9440 - val_loss: 0.4807 - val_accuracy: 0.7692
# Epoch 9/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2000 - accuracy: 0.9224 - val_loss: 0.4681 - val_accuracy: 0.7692
# Epoch 10/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1666 - accuracy: 0.9397 - val_loss: 0.4642 - val_accuracy: 0.7692
# Epoch 11/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1631 - accuracy: 0.9397 - val_loss: 0.4642 - val_accuracy: 0.7692
# Epoch 12/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1155 - accuracy: 0.9569 - val_loss: 0.4918 - val_accuracy: 0.7692
# Epoch 13/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1216 - accuracy: 0.9569 - val_loss: 0.5013 - val_accuracy: 0.7692
# Epoch 14/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1152 - accuracy: 0.9741 - val_loss: 0.5103 - val_accuracy: 0.7692
# Epoch 15/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1060 - accuracy: 0.9828 - val_loss: 0.5183 - val_accuracy: 0.7692
# Epoch 16/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0887 - accuracy: 0.9828 - val_loss: 0.5271 - val_accuracy: 0.7692
# Epoch 17/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0851 - accuracy: 0.9784 - val_loss: 0.5303 - val_accuracy: 0.7692
# Epoch 18/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0725 - accuracy: 0.9784 - val_loss: 0.5493 - val_accuracy: 0.7692
# Epoch 19/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0544 - accuracy: 0.9871 - val_loss: 0.5667 - val_accuracy: 0.7692
# Epoch 20/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0576 - accuracy: 0.9871 - val_loss: 0.5698 - val_accuracy: 0.7692
# Epoch 21/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0611 - accuracy: 0.9957 - val_loss: 0.5643 - val_accuracy: 0.7692
# Epoch 22/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0567 - accuracy: 0.9828 - val_loss: 0.5797 - val_accuracy: 0.7692
# Epoch 23/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0472 - accuracy: 0.9957 - val_loss: 0.5954 - val_accuracy: 0.7692
# Epoch 24/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0515 - accuracy: 0.9957 - val_loss: 0.6023 - val_accuracy: 0.7692
# Epoch 25/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0416 - accuracy: 0.9828 - val_loss: 0.6008 - val_accuracy: 0.8077
# Score for fold 7: loss of 0.60076904296875; accuracy of 80.7692289352417%
# Training for fold 8...
# Epoch 1/25
# 8/8 [==============================] - 1s 30ms/step - loss: 0.6699 - accuracy: 0.5647 - val_loss: 0.6024 - val_accuracy: 0.6923
# Epoch 2/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5814 - accuracy: 0.7328 - val_loss: 0.5166 - val_accuracy: 0.7692
# Epoch 3/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4679 - accuracy: 0.8060 - val_loss: 0.4611 - val_accuracy: 0.7692
# Epoch 4/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3919 - accuracy: 0.8836 - val_loss: 0.4152 - val_accuracy: 0.8077
# Epoch 5/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3411 - accuracy: 0.9138 - val_loss: 0.3777 - val_accuracy: 0.8077
# Epoch 6/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2970 - accuracy: 0.9052 - val_loss: 0.3531 - val_accuracy: 0.8077
# Epoch 7/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2717 - accuracy: 0.8879 - val_loss: 0.3486 - val_accuracy: 0.8462
# Epoch 8/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2465 - accuracy: 0.9095 - val_loss: 0.3538 - val_accuracy: 0.8462
# Epoch 9/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1996 - accuracy: 0.9397 - val_loss: 0.3597 - val_accuracy: 0.8077
# Epoch 10/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1968 - accuracy: 0.9224 - val_loss: 0.3732 - val_accuracy: 0.8462
# Epoch 11/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1944 - accuracy: 0.9181 - val_loss: 0.3910 - val_accuracy: 0.8462
# Epoch 12/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1703 - accuracy: 0.9310 - val_loss: 0.4076 - val_accuracy: 0.8077
# Epoch 13/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1376 - accuracy: 0.9526 - val_loss: 0.4267 - val_accuracy: 0.8077
# Epoch 14/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1325 - accuracy: 0.9655 - val_loss: 0.4375 - val_accuracy: 0.8077
# Epoch 15/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1106 - accuracy: 0.9698 - val_loss: 0.4532 - val_accuracy: 0.8077
# Epoch 16/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1070 - accuracy: 0.9698 - val_loss: 0.4711 - val_accuracy: 0.8077
# Epoch 17/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0963 - accuracy: 0.9698 - val_loss: 0.4826 - val_accuracy: 0.8077
# Epoch 18/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0944 - accuracy: 0.9784 - val_loss: 0.5024 - val_accuracy: 0.8462
# Epoch 19/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0842 - accuracy: 0.9655 - val_loss: 0.5213 - val_accuracy: 0.8462
# Epoch 20/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0719 - accuracy: 0.9784 - val_loss: 0.5518 - val_accuracy: 0.8462
# Epoch 21/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0634 - accuracy: 0.9914 - val_loss: 0.5760 - val_accuracy: 0.8077
# Epoch 22/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0693 - accuracy: 0.9828 - val_loss: 0.5896 - val_accuracy: 0.8077
# Epoch 23/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0524 - accuracy: 0.9957 - val_loss: 0.6007 - val_accuracy: 0.8077
# Epoch 24/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0576 - accuracy: 0.9828 - val_loss: 0.6121 - val_accuracy: 0.8077
# Epoch 25/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0419 - accuracy: 0.9914 - val_loss: 0.6303 - val_accuracy: 0.8077
# Score for fold 8: loss of 0.630285918712616; accuracy of 80.7692289352417%
# Training for fold 9...
# Epoch 1/25
# 8/8 [==============================] - 1s 31ms/step - loss: 0.6987 - accuracy: 0.5451 - val_loss: 0.5650 - val_accuracy: 0.8400
# Epoch 2/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5519 - accuracy: 0.7682 - val_loss: 0.5005 - val_accuracy: 0.9200
# Epoch 3/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4838 - accuracy: 0.7983 - val_loss: 0.4460 - val_accuracy: 0.8800
# Epoch 4/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4041 - accuracy: 0.8627 - val_loss: 0.3984 - val_accuracy: 0.8800
# Epoch 5/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3457 - accuracy: 0.8884 - val_loss: 0.3554 - val_accuracy: 0.8800
# Epoch 6/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3121 - accuracy: 0.9056 - val_loss: 0.3225 - val_accuracy: 0.8800
# Epoch 7/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2533 - accuracy: 0.9185 - val_loss: 0.2967 - val_accuracy: 0.9200
# Epoch 8/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2165 - accuracy: 0.9485 - val_loss: 0.2835 - val_accuracy: 0.9200
# Epoch 9/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1962 - accuracy: 0.9356 - val_loss: 0.2752 - val_accuracy: 0.9200
# Epoch 10/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1811 - accuracy: 0.9270 - val_loss: 0.2717 - val_accuracy: 0.9200
# Epoch 11/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1483 - accuracy: 0.9700 - val_loss: 0.2676 - val_accuracy: 0.8800
# Epoch 12/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1553 - accuracy: 0.9442 - val_loss: 0.2753 - val_accuracy: 0.8800
# Epoch 13/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1163 - accuracy: 0.9742 - val_loss: 0.2848 - val_accuracy: 0.8800
# Epoch 14/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1204 - accuracy: 0.9528 - val_loss: 0.2947 - val_accuracy: 0.8800
# Epoch 15/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1073 - accuracy: 0.9828 - val_loss: 0.3027 - val_accuracy: 0.8800
# Epoch 16/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0963 - accuracy: 0.9657 - val_loss: 0.3019 - val_accuracy: 0.8800
# Epoch 17/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0712 - accuracy: 0.9871 - val_loss: 0.3097 - val_accuracy: 0.8400
# Epoch 18/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0706 - accuracy: 0.9785 - val_loss: 0.3198 - val_accuracy: 0.8400
# Epoch 19/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0715 - accuracy: 0.9828 - val_loss: 0.3294 - val_accuracy: 0.8400
# Epoch 20/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0592 - accuracy: 0.9957 - val_loss: 0.3324 - val_accuracy: 0.8400
# Epoch 21/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0522 - accuracy: 0.9957 - val_loss: 0.3335 - val_accuracy: 0.8400
# Epoch 22/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0531 - accuracy: 0.9785 - val_loss: 0.3389 - val_accuracy: 0.8400
# Epoch 23/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0421 - accuracy: 0.9957 - val_loss: 0.3561 - val_accuracy: 0.8400
# Epoch 24/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0376 - accuracy: 0.9914 - val_loss: 0.3716 - val_accuracy: 0.8400
# Epoch 25/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0435 - accuracy: 0.9871 - val_loss: 0.3870 - val_accuracy: 0.8400
# Score for fold 9: loss of 0.3870251178741455; accuracy of 83.99999737739563%
# Training for fold 10...
# Epoch 1/25
# 8/8 [==============================] - 1s 32ms/step - loss: 0.7567 - accuracy: 0.5365 - val_loss: 0.6768 - val_accuracy: 0.6400
# Epoch 2/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5671 - accuracy: 0.7682 - val_loss: 0.5820 - val_accuracy: 0.7200
# Epoch 3/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5245 - accuracy: 0.7854 - val_loss: 0.5033 - val_accuracy: 0.7600
# Epoch 4/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4364 - accuracy: 0.8369 - val_loss: 0.4435 - val_accuracy: 0.7600
# Epoch 5/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3759 - accuracy: 0.8927 - val_loss: 0.3979 - val_accuracy: 0.8400
# Epoch 6/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3329 - accuracy: 0.8927 - val_loss: 0.3616 - val_accuracy: 0.8400
# Epoch 7/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2973 - accuracy: 0.9013 - val_loss: 0.3373 - val_accuracy: 0.8400
# Epoch 8/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2846 - accuracy: 0.9056 - val_loss: 0.3233 - val_accuracy: 0.8400
# Epoch 9/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2463 - accuracy: 0.9142 - val_loss: 0.3392 - val_accuracy: 0.8800
# Epoch 10/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2116 - accuracy: 0.9313 - val_loss: 0.3385 - val_accuracy: 0.8800
# Epoch 11/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2058 - accuracy: 0.9313 - val_loss: 0.3408 - val_accuracy: 0.8400
# Epoch 12/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1744 - accuracy: 0.9442 - val_loss: 0.3520 - val_accuracy: 0.8800
# Epoch 13/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1587 - accuracy: 0.9528 - val_loss: 0.3656 - val_accuracy: 0.8800
# Epoch 14/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1375 - accuracy: 0.9657 - val_loss: 0.3723 - val_accuracy: 0.8800
# Epoch 15/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1429 - accuracy: 0.9571 - val_loss: 0.3737 - val_accuracy: 0.8800
# Epoch 16/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1177 - accuracy: 0.9657 - val_loss: 0.3762 - val_accuracy: 0.8800
# Epoch 17/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1066 - accuracy: 0.9700 - val_loss: 0.3955 - val_accuracy: 0.8800
# Epoch 18/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1042 - accuracy: 0.9742 - val_loss: 0.4081 - val_accuracy: 0.8800
# Epoch 19/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0839 - accuracy: 0.9828 - val_loss: 0.4327 - val_accuracy: 0.8400
# Epoch 20/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0954 - accuracy: 0.9700 - val_loss: 0.4582 - val_accuracy: 0.8400
# Epoch 21/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0669 - accuracy: 0.9957 - val_loss: 0.4817 - val_accuracy: 0.8400
# Epoch 22/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.4965 - val_accuracy: 0.8400
# Epoch 23/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0566 - accuracy: 0.9914 - val_loss: 0.5034 - val_accuracy: 0.8400
# Epoch 24/25
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0552 - accuracy: 0.9871 - val_loss: 0.5229 - val_accuracy: 0.8400
# Epoch 25/25
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 0.5368 - val_accuracy: 0.8400
# Score for fold 10: loss of 0.5367814898490906; accuracy of 83.99999737739563%
# Average Accuracy: 82.18461394309998%
# Average Loss: 0.5802517265081406
# 7/7 [==============================] - 0s 3ms/step

# %%
# Function to build the model for Step 2
def build_model_step2(input_dim, dropout_rate=0.25):
    model = Sequential([
        Dense(128, activation='relu', input_dim=input_dim),
        Dropout(dropout_rate),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Step 2: Prepare the test set
test_data_step2 = test_data[test_data['Predicted_step1'] == 0]
X_test_step2 = test_data_step2.drop(columns=['Outcome_numerical', 'Predicted_step1'])
y_test_step2 = test_data_step2['Outcome_numerical'].replace(2, 1)  # Re-encode class 2 as 1 for binary classification

# Prepare the training data for Step 2 (binary classification: class 0 vs class 2-as-1)
train_data_step2 = train_data[train_data['Outcome_numerical'] != 1]
X_train_step2 = train_data_step2.drop(columns=['Outcome_numerical', 'Outcome_numerical_step1'])
y_train_step2 = train_data_step2['Outcome_numerical'].replace(2, 1)

# Standardize features for Step 2
scaler_step2 = StandardScaler()
X_train_step2_scaled = scaler_step2.fit_transform(X_train_step2)

# Apply SMOTE for Step 2 to handle class imbalance
smote = SMOTE(random_state=42)
X_train_step2_smote, y_train_step2_smote = smote.fit_resample(X_train_step2_scaled, y_train_step2)

# Initialize the MLP model
model_step2 = build_model_step2(X_train_step2_smote.shape[1])

# Train the MLP model with specified parameters
model_step2.fit(X_train_step2_smote, y_train_step2_smote, epochs=10, batch_size=16, verbose=1)

# Scale features for Step 2 in the test set
X_test_step2_scaled = scaler_step2.transform(X_test_step2)

# Make predictions for Step 2
y_pred_step2 = (model_step2.predict(X_test_step2_scaled) > 0.5).astype(int)

# Calculate and display evaluation metrics for Step 2
accuracy_step2 = accuracy_score(y_test_step2, y_pred_step2)
precision_step2 = precision_score(y_test_step2, y_pred_step2)
recall_step2 = recall_score(y_test_step2, y_pred_step2)
f1_step2 = f1_score(y_test_step2, y_pred_step2)

print(f"Step 2 Accuracy: {accuracy_step2}")
print(f"Step 2 Precision: {precision_step2}")
print(f"Step 2 Recall: {recall_step2}")
print(f"Step 2 F1 Score: {f1_step2}")

# Visualize the confusion matrix for Step 2
conf_matrix_step2 = confusion_matrix(y_test_step2, y_pred_step2)
fig, ax = plt.subplots(figsize=(8, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_step2, display_labels=[0, '2-as-1'])
disp.plot(cmap=plt.cm.Blues, ax=ax)
ax.set_title('Step 2: Confusion Matrix - Binary Classification between Class 0 and Class 2-as-1')
plt.show()
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 4ms/step - loss: 0.6913 - accuracy: 0.5823
# Epoch 2/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5643 - accuracy: 0.7152
# Epoch 3/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4415 - accuracy: 0.8544
# Epoch 4/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3869 - accuracy: 0.8544
# Epoch 5/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3202 - accuracy: 0.9114
# Epoch 6/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2543 - accuracy: 0.9557
# Epoch 7/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2205 - accuracy: 0.9494
# Epoch 8/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1626 - accuracy: 0.9684
# Epoch 9/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9937
# Epoch 10/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1057 - accuracy: 0.9937
# 3/3 [==============================] - 0s 6ms/step
# Step 2 Accuracy: 0.6593406593406593
# Step 2 Precision: 0.625
# Step 2 Recall: 0.40540540540540543
# Step 2 F1 Score: 0.4918032786885246

# %%
# Step 2 re-encoding needs to be reversed for the final classification
# 0 remains 0, 1 (re-encoded class 2) needs to be turned back to 2
test_data.loc[test_data_step2.index, 'Predicted_step2'] = y_pred_step2
test_data.loc[test_data_step2.index, 'Predicted_step2'] = test_data['Predicted_step2'].replace(1, 2)

# Combine Step 1 and Step 2 predictions into a final classification result
def combine_predictions(row):
    if row['Predicted_step1'] == 1:
        return 1  # Direct classification as class 1
    else:
        return row['Predicted_step2']  # Either 0 or 2 as classified in Step 2

test_data['Final_Prediction'] = test_data.apply(combine_predictions, axis=1)

# Evaluation with the original classes
y_true = test_data['Outcome_numerical']  # Assuming this column has the original class labels
y_pred_final = test_data['Final_Prediction']

# Calculate and display evaluation metrics for the final three-class classification
accuracy_final = accuracy_score(y_true, y_pred_final)
precision_final = precision_score(y_true, y_pred_final, average='macro')
recall_final = recall_score(y_true, y_pred_final, average='macro')
f1_final = f1_score(y_true, y_pred_final, average='macro')

print(f"Final Model Accuracy: {accuracy_final}")
print(f"Final Model Precision: {precision_final}")
print(f"Final Model Recall: {recall_final}")
print(f"Final Model F1 Score: {f1_final}")

# Visualize the final confusion matrix
conf_matrix_final = confusion_matrix(y_true, y_pred_final)
fig, ax = plt.subplots(figsize=(8, 8))
disp_final = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_final, display_labels=[0, 1, 2])
disp_final.plot(cmap=plt.cm.Blues, ax=ax)
ax.set_title('Final Confusion Matrix - Three-Class Classification')
plt.show()
# Out:
# Final Model Accuracy: 0.7783018867924528
# Final Model Precision: 0.6992019927908667
# Final Model Recall: 0.699062980030722
# Final Model F1 Score: 0.6987964416535846

# %%
# Calculate and display evaluation metrics for the final three-class classification
accuracy_final = accuracy_score(y_true, y_pred_final)
precision_final = precision_score(y_true, y_pred_final, average=None)  # Changed to None for individual class scores
recall_final = recall_score(y_true, y_pred_final, average=None)  
f1_final = f1_score(y_true, y_pred_final, average=None)  
conf_matrix_final = confusion_matrix(y_true, y_pred_final)

class_labels = ['Severe', 'Non Severe', 'Deceased']

# Creating a figure and a set of subplots
fig, axes = plt.subplots(1, 2, figsize=(20, 8))
bone_palette = plt.cm.bone(np.linspace(0.3, 0.6, 3))

bar_width = 0.25
index = np.arange(len(class_labels))

# Plotting precision, recall, and F1-score for each class
axes[0].bar(index, precision_final, bar_width, color=bone_palette[0], label='Precision')
axes[0].bar(index + bar_width, recall_final, bar_width, color=bone_palette[1], label='Recall')
axes[0].bar(index + 2 * bar_width, f1_final, bar_width, color=bone_palette[2], label='F1 Score')

# Setting labels and titles
axes[0].set_xlabel('Classes', fontsize=14)
axes[0].set_ylabel('Scores', fontsize=14)
axes[0].set_title('2-Step Class Metrics - 2 Optimized MLPs', fontsize=16)
axes[0].set_xticks(index + bar_width)
axes[0].set_xticklabels(class_labels)
axes[0].legend()

# Adding text annotations for clarity
for i in range(len(class_labels)):
    axes[0].text(i, precision_final[i] + 0.02, f'{precision_final[i]:.2f}', ha='center', va='bottom')
    axes[0].text(i + bar_width, recall_final[i] + 0.02, f'{recall_final[i]:.2f}', ha='center', va='bottom')
    axes[0].text(i + 2 * bar_width, f1_final[i] + 0.02, f'{f1_final[i]:.2f}', ha='center', va='bottom')

axes[0].text(len(class_labels), 0, f'T. Accuracy:\n{accuracy_final:.2f}', fontsize=14, ha='center')
# Confusion Matrix Display
conf_matrix_disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_final, display_labels=class_labels)
conf_matrix_disp.plot(cmap=plt.cm.bone_r, ax=axes[1], colorbar=True)
axes[1].set_title('Final MLP Confusion Matrix - Three-Class Classification', fontsize=16)

plt.tight_layout()
plt.show()
